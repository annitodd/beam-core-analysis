# %%
import pandas as pd
# pd.set_option("max_column", None)

# %%
skimsTransitCrowding = pd.read_csv('1.String _ skimsTransitCrowding.csv.gz')

# %%
skimsTransitCrowding['firstTwo'] = skimsTransitCrowding['vehicleId'].str[:2]

# %%
skimsTransitCrowding['lastSeven'] = skimsTransitCrowding['vehicleId'].str[-7:]

# %%
skimsTransitCrowding
# Out:
#          vehicleId  fromStopIdx  numberOfPassengers  capacity  observations  \
# 0       SF:7678176           12                   5        28             1
# 1       VT:2222935           11                  18        23             1
# 2       BA:61SFO11            9                  69       421             1
# 3       SF:7628729            7                   4        22             1
# 4       SF:7676796           21                   2        28             1
# ...            ...          ...                 ...       ...           ...
# 103297  SF:7634325           15                   1        28             1
# 103298  BA:91SFO10           18                  56       421             1
# 103299  SF:7676907           23                   2        28             1
# 103300  SF:7631663           11                   6        22             1
# 103301  SF:7634205           12                   5        28             1
#
#         iterations firstTwo lastSeven
# ...

# %%
skimsTransitCrowding['firstTwo'].unique()
# Out:
# array(['SF', 'VT', 'BA', 'SC', 'ca', 'AM', 'CE', 'HF'], dtype=object)

# %%
events = pd.read_csv('0.3pop-sfbay-no-car-1600.csv.gz')
# Out:
# /usr/local/Cellar/jupyterlab/3.2.5/libexec/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (0,1,2,7,8,22,24,25,28,29,31,33,35,36,37,38,48,49,50,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pathTraversal = events[events['type'] == 'PathTraversal'].dropna(how='all', axis=1)

# %%
pathTraversal.columns
# Out:
# Index(['mode', 'vehicleType', 'links', 'numPassengers', 'length',
#        'primaryFuel', 'vehicle', 'driver', 'riders', 'toStopIndex',
#        'fromStopIndex', 'seatingCapacity', 'tollPaid', 'secondaryFuelLevel',
#        'primaryFuelLevel', 'endY', 'endX', 'startY', 'startX', 'capacity',
#        'arrivalTime', 'departureTime', 'linkTravelTime', 'secondaryFuel',
#        'secondaryFuelType', 'primaryFuelType', 'time', 'type'],
#       dtype='object')

# %%
pathTraversal['primaryFuelType'].unique()
# Out:
# array(['Gasoline', 'Diesel', 'Biodiesel', 'Electricity', 'Food'],
#       dtype=object)

# %%
pathTraversal['secondaryFuelType'].unique()
# Out:
# array(['None', 'Gasoline'], dtype=object)

# %%
transit = pathTraversal[pathTraversal['driver'].str[:7] == 'Transit']

# %%
transit = transit[transit['time'] <= 86400]

# %%
transit['firstTwo'] = transit['vehicle'].str[:2]
# Out:
# /var/folders/z4/5gq1j4sn50b62w40lgwsthh80000gn/T/ipykernel_16309/3191282495.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   transit['firstTwo'] = transit['vehicle'].str[:2]

# %%
transit
# Out:
#          mode  vehicleType                                              links  \
# 36024     bus       BUS-MA  20393,134727,134715,17955,17951,132987,17949,7...
# 85481     bus       BUS-MA  20393,134727,134715,17955,17951,132987,17949,7...
# 149932    bus       BUS-MA         20389,16787,15697,15698,35152,35151,133091
# 149933    bus       BUS-MA         20389,16787,15697,15698,35152,35151,133091
# 149934    bus       BUS-MA             133091,133087,21883,21448,133066,21450
# ...       ...          ...                                                ...
# 78487018  bus       BUS-AC                 105683,122179,105639,122845,106073
# 78487020  bus  BUS-DEFAULT                                        86233,86232
# 78487022  bus  BUS-DEFAULT                                        86233,86232
# 78487122  bus  BUS-DEFAULT  69524,69527,55086,16845,16842,17474,145370,140...
# 78487179  bus  BUS-DEFAULT  26466,161854,161858,36446,161202,36449,29470,1...
#
# ...

# %%
transit.groupby('firstTwo').sum()
# Out:
#           numPassengers        length   primaryFuel  toStopIndex  \
# firstTwo
# 3D             182910.0  1.286819e+07  2.579816e+11          0.0
# AC            2470057.0  1.184748e+08  2.375183e+12          0.0
# AM              17742.0  2.874635e+06  0.000000e+00       1200.0
# AY                103.0  4.113878e+04  8.056043e+08          0.0
# BA            1526086.0  4.551004e+07  0.000000e+00     143121.0
# CC             364804.0  3.236463e+07  5.840697e+11          0.0
# CE               2705.0  1.152072e+06  0.000000e+00        360.0
# CM               8192.0  3.531848e+06  6.916276e+10          0.0
# CT             121412.0  3.242246e+07  5.664333e+11          0.0
# DE              11561.0  2.868782e+06  5.176286e+10          0.0
# EM               8270.0  2.729103e+06  5.471306e+10          0.0
# GG             311533.0  6.135595e+07  1.071913e+12          0.0
# HF                  0.0  7.146331e+04  0.000000e+00         27.0
# ...

# %%
'SF', 'VT', 'BA', 'SC', 'ca', 'AM', 'CE', 'HF'
1545794.0, 2661560.0, 1526086.0, 534.0, 236343.0, 17742.0, 2705.0,
