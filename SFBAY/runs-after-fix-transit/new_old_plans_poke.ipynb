# %%
import pandas as pd

# %%
newPlans = pd.read_csv('new-plans.csv.gz')

# %%
olderPlans = pd.read_csv('older-plans.csv.gz')

# %%
newPlans
# Out:
#               trip_id  person_id  number_of_participants       trip_mode  \
# 0                 NaN        4.0                     NaN             NaN
# 1        1.513000e+03        4.0                     1.0  DRIVEALONEFREE
# 2                 NaN        4.0                     NaN             NaN
# 3        1.517000e+03        4.0                     1.0  DRIVEALONEFREE
# 4                 NaN        4.0                     NaN             NaN
# ...               ...        ...                     ...             ...
# 3303456           NaN  6808834.0                     NaN             NaN
# 3303457  2.233298e+09  6808834.0                     1.0   DRIVEALONEPAY
# 3303458           NaN  6808834.0                     NaN             NaN
# 3303459  2.233298e+09  6808834.0                     1.0  DRIVEALONEFREE
# 3303460           NaN  6808834.0                     NaN             NaN
#
#          PlanElementIndex ActivityElement ActivityType           x          y  \
# ...

# %%
olderPlans
# Out:
#           Unnamed: 0       trip_id  person_id  number_of_participants  \
# 0                  0           NaN        0.0                     NaN
# 1                  1  7.300000e+01        0.0                     1.0
# 2                  1           NaN        0.0                     NaN
# 3                  2  7.700000e+01        0.0                     1.0
# 4                  2           NaN        0.0                     NaN
# ...              ...           ...        ...                     ...
# 53229581    29622305           NaN  6741461.0                     NaN
# 53229582    29622306  2.211199e+09  6741461.0                     1.0
# 53229583    29622306           NaN  6741461.0                     NaN
# 53229584    29622307  2.211199e+09  6741461.0                     1.0
# 53229585    29622307           NaN  6741461.0                     NaN
#
#             trip_mode  PlanElementIndex ActivityElement ActivityType  \
# ...
